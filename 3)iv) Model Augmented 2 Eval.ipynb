# %%
import os
import cv2
import random
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go


from deepface import DeepFace

from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score


from collections import Counter
# Out:
# WARNING:tensorflow:From c:\Users\User\Desktop\Face_Recognition_System_Model\.venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Step 1: Evaluate Deepface Models
#
# - Facenet
# - Facenet512
# - GhostFaceNet
# - ArcFace
# - SFace
# - Dlib

# %%
def evaluate_multiclass_one_ori_against_aug(
    data_dir,
    model_name="Facenet",
    enforce_detection=False,
    title="Multi-class Face Recognition (One ORI vs. AUG)"
):
    """
    Performs multi-class face recognition in a dataset where each subfolder represents a class.
    Each class folder contains multiple images, including at least one 'ori_' image and 
    multiple 'aug_' images.

    1. For each class, pick exactly one 'ori_' image as the reference (enrollment) image.
    2. Compute embeddings for all 'aug_' images across all classes, comparing each to every 
       class's reference embedding (Euclidean distance).
    3. Assign each 'aug_' image to the class with the nearest reference embedding.
    4. Generate a multi-class classification report.
    """

    # 1. Gather all classes and separate 'ori_' from 'aug_' images
    subfolders = [f.path for f in os.scandir(data_dir) if f.is_dir()]

    # We'll store references in a dict: { class_name: embedding_of_one_ori (as a NumPy array) }
    class_reference_embeddings = {}
    # We'll store test images in a list of (img_path, class_name)
    test_images = []

    for subfolder in subfolders:
        class_name = os.path.basename(subfolder)
        all_images = [
            os.path.join(subfolder, img)
            for img in os.listdir(subfolder)
            if img.lower().endswith((".jpg", ".jpeg", ".png"))
        ]

        # Separate ori_ and aug_ images
        ori_imgs = [img for img in all_images if "ori_" in os.path.basename(img)]
        aug_imgs = [img for img in all_images if "aug_" in os.path.basename(img)]

        # Pick exactly one ori_ image as the reference (e.g., the first one if multiple exist)
        if ori_imgs:
            reference_img = ori_imgs[0]  # pick the first
            try:
                rep = DeepFace.represent(
                    reference_img,
                    model_name=model_name,
                    enforce_detection=enforce_detection
                )
                if rep and len(rep) > 0:
                    # Convert the embedding list to a NumPy array
                    emb_array = np.array(rep[0]["embedding"], dtype=np.float32)
                    class_reference_embeddings[class_name] = emb_array
                else:
                    print(f"Warning: No embedding found for {reference_img}. Skipping class '{class_name}'")
                    continue
            except Exception as e:
                print(f"Error generating embedding for {reference_img}: {e}")
                continue
        else:
            # If there's no ori image, skip the class
            print(f"Warning: No 'ori_' image found for class '{class_name}'. Skipping.")
            continue

        # All aug_ images become test images
        for aug_img in aug_imgs:
            test_images.append((aug_img, class_name))

    if not class_reference_embeddings:
        print("No classes with valid reference embeddings found.")
        return {}

    if not test_images:
        print("No test (aug) images found.")
        return {}

    # 2. For each test image, find the class with the nearest reference embedding
    true_labels = []
    pred_labels = []

    for (img_path, true_class) in test_images:
        true_labels.append(true_class)

        try:
            rep = DeepFace.represent(
                img_path,
                model_name=model_name,
                enforce_detection=enforce_detection
            )
            if rep and len(rep) > 0:
                # Convert the embedding list to a NumPy array
                emb = np.array(rep[0]["embedding"], dtype=np.float32)
            else:
                # If no embedding, label as "Unknown"
                pred_labels.append("Unknown")
                continue
        except Exception as e:
            print(f"Error generating embedding for {img_path}: {e}")
            pred_labels.append("Unknown")
            continue

        # Compute Euclidean distance to each class reference
        best_class = None
        best_dist = float("inf")
        for c_name, c_emb in class_reference_embeddings.items():
            # Now c_emb and emb are both NumPy arrays, so subtraction works
            dist = np.linalg.norm(emb - c_emb)
            if dist < best_dist:
                best_dist = dist
                best_class = c_name

        if best_class is not None:
            pred_labels.append(best_class)
        else:
            pred_labels.append("Unknown")

    # 3. Compute multi-class metrics
    all_classes = sorted(class_reference_embeddings.keys())
    # If "Unknown" is in predictions, optionally add it to the label set
    if "Unknown" in pred_labels:
        all_classes += ["Unknown"]

    accuracy = accuracy_score(true_labels, pred_labels)
    precision = precision_score(true_labels, pred_labels, average="macro", zero_division=0)
    recall = recall_score(true_labels, pred_labels, average="macro", zero_division=0)
    f1 = f1_score(true_labels, pred_labels, average="macro", zero_division=0)

    print(title)
    print("=" * len(title))
    print(f"Accuracy : {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall   : {recall:.4f}")
    print(f"F1-score : {f1:.4f}\n")

    # Print full classification report
    from sklearn.metrics import classification_report
    report = classification_report(true_labels, pred_labels, labels=all_classes, zero_division=0)
    print("Full Classification Report:")
    print(report)

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }

# %%
test_data_dir = "lfw-deepfunneled-augmentedV2-test" # Test dataset directory

evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - Facenet Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="Facenet",
    enforce_detection=False,
)
# Out:
# DeepFace - Facenet Multi-class Face Recognition (One ORI vs. AUG)
# =================================================================
# Accuracy : 0.6360
# Precision: 0.9185
# Recall   : 0.6360
# F1-score : 0.7193
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       0.67      0.20      0.31        10
#                   Bill_Nelson       1.00      0.90      0.95        10
#              Boris_Berezovsky       1.00      0.50      0.67        10
#                   Brian_Cowen       1.00      0.70      0.82        10
#                    Cesar_Maia       0.83      0.50      0.62        10
#               Charles_Kartman       1.00      0.60      0.75        10
#               Charles_Schumer       1.00      0.60      0.75        10
#                 Chen_Liang_Yu       1.00      0.90      0.95        10
#                  Chris_Tucker       1.00      0.90      0.95        10
#                   Chuck_Amato       1.00      0.80      0.89        10
#                Chung_Mong-hun       0.26      0.60      0.36        10
#                   David_Spade       1.00      0.50      0.67        10
#                Denise_Johnson       1.00      0.30      0.46        10
#               Dennis_Erickson       1.00      0.90      0.95        10
#                 Dennis_Powell       0.78      0.70      0.74        10
#                 Dolma_Tsering       1.00      0.70      0.82        10
#                   Doug_Duncan       1.00      0.90      0.95        10
#                   Eddy_Merckx       1.00      0.60      0.75        10
#              Elizabeth_Taylor       1.00      0.30      0.46        10
#               Ellen_DeGeneres       1.00      0.60      0.75        10
#                  Emile_Lahoud       1.00      0.50      0.67        10
#             Erika_Christensen       1.00      0.80      0.89        10
#             Evander_Holyfield       1.00      0.60      0.75        10
#                Francis_George       1.00      0.40      0.57        10
#                Garry_Kasparov       1.00      0.90      0.95        10
#                   Gary_Forsee       1.00      0.40      0.57        10
#                 Gary_Williams       1.00      0.40      0.57        10
#                  Gary_Winnick       1.00      0.50      0.67        10
#               George_Roy_Hill       1.00      0.50      0.67        10
#              Gerard_Depardieu       1.00      0.40      0.57        10
#                 Gregory_Hines       1.00      0.80      0.89        10
#                 Hanan_Ashrawi       1.00      0.80      0.89        10
#                 Hideki_Matsui       1.00      0.70      0.82        10
#                Hootie_Johnson       0.50      0.30      0.38        10
#                  Howard_Smith       0.86      0.60      0.71        10
#                     Iban_Mayo       1.00      0.70      0.82        10
#                    Iva_Majoli       0.04      0.70      0.08        10
#           Jacqueline_Obradors       1.00      0.90      0.95        10
#            Jada_Pinkett_Smith       1.00      0.80      0.89        10
#                 James_Schultz       1.00      0.70      0.82        10
#           Jean-Claude_Juncker       0.86      0.60      0.71        10
#         Jeffrey_Scott_Postell       1.00      0.80      0.89        10
#             Jennifer_Thompson       0.78      0.70      0.74        10
#                 Jerry_Falwell       1.00      0.40      0.57        10
#                  John_Spencer       0.88      0.70      0.78        10
# Jorge_Rodolfo_Canicoba_Corral       0.86      0.60      0.71        10
#                    Judi_Dench       1.00      0.70      0.82        10
#                 Justin_Gatlin       0.88      0.70      0.78        10
#                 Kathy_Winters       1.00      0.90      0.95        10
#                 Kenneth_Evans       0.75      0.60      0.67        10
#            Kieran_Prendergast       1.00      0.70      0.82        10
#                  Kurt_Russell       1.00      0.70      0.82        10
#             Lawrence_MacAulay       1.00      1.00      1.00        10
#                       Lee_Jun       1.00      0.80      0.89        10
#                Leland_Chapman       1.00      0.60      0.75        10
#                 Lindsay_Benko       1.00      0.80      0.89        10
#                Marilyn_Monroe       1.00      0.40      0.57        10
#                    Mark_Cuban       1.00      0.70      0.82        10
#                 Mark_Hamister       1.00      0.70      0.82        10
#              Miguel_Contreras       0.26      0.50      0.34        10
#             Mikhail_Gorbachev       0.89      0.80      0.84        10
#              Mikulas_Dzurinda       1.00      0.70      0.82        10
#                Morgan_Freeman       1.00      0.30      0.46        10
#                   Nancy_Demme       1.00      0.80      0.89        10
#                   Nathan_Lane       1.00      0.30      0.46        10
#                  Nicholas_Tse       1.00      0.50      0.67        10
#                Nicolas_Escude       1.00      0.90      0.95        10
#          Nursultan_Nazarbayev       1.00      0.70      0.82        10
#                     Pat_Burns       1.00      0.90      0.95        10
#                       Pat_Cox       0.26      0.70      0.38        10
#                 Patrick_Ewing       0.67      0.60      0.63        10
#                Peter_Costello       1.00      0.50      0.67        10
#               Peter_Greenaway       1.00      0.80      0.89        10
#                Phil_Mickelson       0.03      0.40      0.06        10
#               Philippe_Noiret       1.00      0.50      0.67        10
#               Princess_Masako       1.00      0.70      0.82        10
#                   Ralph_Klein       1.00      0.80      0.89        10
#          Ricardo_Lopez_Murphy       1.00      1.00      1.00        10
#                 Richard_Haass       1.00      0.70      0.82        10
#              Richard_Sambrook       1.00      0.70      0.82        10
#                  Ricky_Martin       1.00      0.30      0.46        10
#              Robert_Blackwill       0.86      0.60      0.71        10
#                   Robert_Fico       1.00      0.50      0.67        10
#                 Robert_Mugabe       1.00      0.80      0.89        10
#               Rod_Blagojevich       1.00      0.90      0.95        10
#                Rogerio_Romero       1.00      0.80      0.89        10
#                  Scott_Ritter       1.00      0.90      0.95        10
#              Silvio_Fernandez       1.00      0.20      0.33        10
#                Stephen_Daldry       1.00      0.30      0.46        10
#              Stephen_Friedman       1.00      0.30      0.46        10
#                 Terrell_Suggs       0.75      0.90      0.82        10
#                Thomas_Malchow       1.00      0.60      0.75        10
#                     Tom_Jones       0.67      0.20      0.31        10
#                 Tracy_McGrady       1.00      0.50      0.67        10
#                    Tyra_Banks       1.00      0.90      0.95        10
#                  Vaclav_Klaus       1.00      0.10      0.18        10
#                  Wesley_Clark       1.00      0.40      0.57        10
#                  Yossi_Beilin       0.53      0.80      0.64        10
#                  Yuri_Fedotov       1.00      0.60      0.75        10
#
#                      accuracy                           0.64      1000
#                     macro avg       0.92      0.64      0.72      1000
#                  weighted avg       0.92      0.64      0.72      1000
# {'accuracy': 0.636,
#  'precision': 0.9184704513201984,
#  'recall': 0.6359999999999999,
#  'f1_score': 0.719289206712418}

# %%
evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - Facenet512 Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="Facenet512",
    enforce_detection=False,
)
# Out:
# DeepFace - Facenet512 Multi-class Face Recognition (One ORI vs. AUG)
# ====================================================================
# Accuracy : 0.7730
# Precision: 0.9177
# Recall   : 0.7730
# F1-score : 0.8196
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       0.67      0.20      0.31        10
#                   Bill_Nelson       1.00      0.90      0.95        10
#              Boris_Berezovsky       1.00      0.80      0.89        10
#                   Brian_Cowen       0.89      0.80      0.84        10
#                    Cesar_Maia       1.00      0.50      0.67        10
#               Charles_Kartman       0.64      0.70      0.67        10
#               Charles_Schumer       1.00      0.60      0.75        10
#                 Chen_Liang_Yu       0.90      0.90      0.90        10
#                  Chris_Tucker       0.56      1.00      0.71        10
#                   Chuck_Amato       0.90      0.90      0.90        10
#                Chung_Mong-hun       0.33      0.50      0.40        10
#                   David_Spade       1.00      0.60      0.75        10
#                Denise_Johnson       1.00      0.70      0.82        10
#               Dennis_Erickson       1.00      0.90      0.95        10
#                 Dennis_Powell       1.00      0.80      0.89        10
#                 Dolma_Tsering       0.80      0.80      0.80        10
#                   Doug_Duncan       1.00      0.90      0.95        10
#                   Eddy_Merckx       0.88      0.70      0.78        10
#              Elizabeth_Taylor       1.00      0.60      0.75        10
#               Ellen_DeGeneres       1.00      0.70      0.82        10
#                  Emile_Lahoud       1.00      0.80      0.89        10
#             Erika_Christensen       1.00      0.90      0.95        10
#             Evander_Holyfield       1.00      0.70      0.82        10
#                Francis_George       1.00      0.90      0.95        10
#                Garry_Kasparov       1.00      0.90      0.95        10
#                   Gary_Forsee       1.00      0.70      0.82        10
#                 Gary_Williams       1.00      0.70      0.82        10
#                  Gary_Winnick       1.00      0.60      0.75        10
#               George_Roy_Hill       1.00      0.80      0.89        10
#              Gerard_Depardieu       1.00      0.50      0.67        10
#                 Gregory_Hines       1.00      0.80      0.89        10
#                 Hanan_Ashrawi       1.00      0.90      0.95        10
#                 Hideki_Matsui       0.89      0.80      0.84        10
#                Hootie_Johnson       0.06      0.60      0.12        10
#                  Howard_Smith       0.89      0.80      0.84        10
#                     Iban_Mayo       1.00      0.70      0.82        10
#                    Iva_Majoli       0.33      0.60      0.43        10
#           Jacqueline_Obradors       1.00      0.90      0.95        10
#            Jada_Pinkett_Smith       1.00      1.00      1.00        10
#                 James_Schultz       0.80      0.80      0.80        10
#           Jean-Claude_Juncker       0.58      0.70      0.64        10
#         Jeffrey_Scott_Postell       1.00      1.00      1.00        10
#             Jennifer_Thompson       1.00      0.90      0.95        10
#                 Jerry_Falwell       0.67      0.40      0.50        10
#                  John_Spencer       1.00      1.00      1.00        10
# Jorge_Rodolfo_Canicoba_Corral       1.00      0.90      0.95        10
#                    Judi_Dench       1.00      1.00      1.00        10
#                 Justin_Gatlin       0.78      0.70      0.74        10
#                 Kathy_Winters       1.00      0.90      0.95        10
#                 Kenneth_Evans       1.00      0.70      0.82        10
#            Kieran_Prendergast       1.00      0.70      0.82        10
#                  Kurt_Russell       1.00      0.80      0.89        10
#             Lawrence_MacAulay       1.00      1.00      1.00        10
#                       Lee_Jun       1.00      1.00      1.00        10
#                Leland_Chapman       1.00      0.60      0.75        10
#                 Lindsay_Benko       1.00      0.90      0.95        10
#                Marilyn_Monroe       1.00      0.40      0.57        10
#                    Mark_Cuban       1.00      1.00      1.00        10
#                 Mark_Hamister       0.90      0.90      0.90        10
#              Miguel_Contreras       1.00      0.40      0.57        10
#             Mikhail_Gorbachev       0.90      0.90      0.90        10
#              Mikulas_Dzurinda       1.00      0.90      0.95        10
#                Morgan_Freeman       1.00      1.00      1.00        10
#                   Nancy_Demme       1.00      0.80      0.89        10
#                   Nathan_Lane       1.00      0.90      0.95        10
#                  Nicholas_Tse       1.00      0.70      0.82        10
#                Nicolas_Escude       1.00      1.00      1.00        10
#          Nursultan_Nazarbayev       1.00      0.80      0.89        10
#                     Pat_Burns       1.00      0.90      0.95        10
#                       Pat_Cox       1.00      1.00      1.00        10
#                 Patrick_Ewing       1.00      0.40      0.57        10
#                Peter_Costello       1.00      0.70      0.82        10
#               Peter_Greenaway       0.82      0.90      0.86        10
#                Phil_Mickelson       0.09      0.70      0.16        10
#               Philippe_Noiret       0.83      0.50      0.62        10
#               Princess_Masako       1.00      0.90      0.95        10
#                   Ralph_Klein       1.00      0.80      0.89        10
#          Ricardo_Lopez_Murphy       1.00      1.00      1.00        10
#                 Richard_Haass       0.91      1.00      0.95        10
#              Richard_Sambrook       0.78      0.70      0.74        10
#                  Ricky_Martin       1.00      0.80      0.89        10
#              Robert_Blackwill       0.86      0.60      0.71        10
#                   Robert_Fico       1.00      0.80      0.89        10
#                 Robert_Mugabe       1.00      0.80      0.89        10
#               Rod_Blagojevich       1.00      1.00      1.00        10
#                Rogerio_Romero       1.00      1.00      1.00        10
#                  Scott_Ritter       1.00      0.90      0.95        10
#              Silvio_Fernandez       1.00      0.20      0.33        10
#                Stephen_Daldry       1.00      0.60      0.75        10
#              Stephen_Friedman       1.00      0.90      0.95        10
#                 Terrell_Suggs       0.78      0.70      0.74        10
#                Thomas_Malchow       1.00      0.90      0.95        10
#                     Tom_Jones       0.86      0.60      0.71        10
#                 Tracy_McGrady       1.00      0.80      0.89        10
#                    Tyra_Banks       1.00      0.90      0.95        10
#                  Vaclav_Klaus       1.00      0.40      0.57        10
#                  Wesley_Clark       0.71      0.50      0.59        10
#                  Yossi_Beilin       0.89      0.80      0.84        10
#                  Yuri_Fedotov       0.89      0.80      0.84        10
#
#                      accuracy                           0.77      1000
#                     macro avg       0.92      0.77      0.82      1000
#                  weighted avg       0.92      0.77      0.82      1000
# {'accuracy': 0.773,
#  'precision': 0.9177314284259972,
#  'recall': 0.7730000000000001,
#  'f1_score': 0.8195570833215551}

# %%
evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - GhostFaceNet Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="GhostFaceNet",
    enforce_detection=False,
)
# Out:
# DeepFace - GhostFaceNet Multi-class Face Recognition (One ORI vs. AUG)
# ======================================================================
# Accuracy : 0.6730
# Precision: 0.9452
# Recall   : 0.6730
# F1-score : 0.7559
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       1.00      0.50      0.67        10
#                   Bill_Nelson       1.00      0.90      0.95        10
#              Boris_Berezovsky       1.00      0.50      0.67        10
#                   Brian_Cowen       1.00      0.70      0.82        10
#                    Cesar_Maia       1.00      0.50      0.67        10
#               Charles_Kartman       1.00      0.60      0.75        10
#               Charles_Schumer       1.00      0.60      0.75        10
#                 Chen_Liang_Yu       1.00      0.90      0.95        10
#                  Chris_Tucker       1.00      0.70      0.82        10
#                   Chuck_Amato       1.00      0.80      0.89        10
#                Chung_Mong-hun       0.07      0.50      0.13        10
#                   David_Spade       1.00      0.70      0.82        10
#                Denise_Johnson       1.00      0.30      0.46        10
#               Dennis_Erickson       1.00      0.90      0.95        10
#                 Dennis_Powell       1.00      0.80      0.89        10
#                 Dolma_Tsering       0.58      0.70      0.64        10
#                   Doug_Duncan       1.00      0.80      0.89        10
#                   Eddy_Merckx       1.00      0.60      0.75        10
#              Elizabeth_Taylor       1.00      0.30      0.46        10
#               Ellen_DeGeneres       0.75      0.60      0.67        10
#                  Emile_Lahoud       0.75      0.30      0.43        10
#             Erika_Christensen       0.80      0.80      0.80        10
#             Evander_Holyfield       1.00      0.60      0.75        10
#                Francis_George       1.00      0.60      0.75        10
#                Garry_Kasparov       1.00      0.90      0.95        10
#                   Gary_Forsee       1.00      0.40      0.57        10
#                 Gary_Williams       1.00      0.80      0.89        10
#                  Gary_Winnick       1.00      0.60      0.75        10
#               George_Roy_Hill       1.00      0.60      0.75        10
#              Gerard_Depardieu       1.00      0.40      0.57        10
#                 Gregory_Hines       1.00      0.80      0.89        10
#                 Hanan_Ashrawi       1.00      0.80      0.89        10
#                 Hideki_Matsui       1.00      0.70      0.82        10
#                Hootie_Johnson       0.07      0.70      0.12        10
#                  Howard_Smith       1.00      0.80      0.89        10
#                     Iban_Mayo       1.00      0.60      0.75        10
#                    Iva_Majoli       0.09      0.40      0.14        10
#           Jacqueline_Obradors       1.00      0.90      0.95        10
#            Jada_Pinkett_Smith       1.00      0.70      0.82        10
#                 James_Schultz       1.00      0.80      0.89        10
#           Jean-Claude_Juncker       1.00      0.50      0.67        10
#         Jeffrey_Scott_Postell       1.00      0.90      0.95        10
#             Jennifer_Thompson       1.00      0.70      0.82        10
#                 Jerry_Falwell       1.00      0.90      0.95        10
#                  John_Spencer       1.00      0.70      0.82        10
# Jorge_Rodolfo_Canicoba_Corral       1.00      0.60      0.75        10
#                    Judi_Dench       1.00      0.70      0.82        10
#                 Justin_Gatlin       1.00      0.30      0.46        10
#                 Kathy_Winters       1.00      0.90      0.95        10
#                 Kenneth_Evans       1.00      0.60      0.75        10
#            Kieran_Prendergast       1.00      0.70      0.82        10
#                  Kurt_Russell       1.00      0.70      0.82        10
#             Lawrence_MacAulay       0.91      1.00      0.95        10
#                       Lee_Jun       1.00      0.80      0.89        10
#                Leland_Chapman       1.00      0.50      0.67        10
#                 Lindsay_Benko       1.00      0.80      0.89        10
#                Marilyn_Monroe       1.00      0.20      0.33        10
#                    Mark_Cuban       1.00      0.70      0.82        10
#                 Mark_Hamister       1.00      0.70      0.82        10
#              Miguel_Contreras       0.86      0.60      0.71        10
#             Mikhail_Gorbachev       1.00      0.90      0.95        10
#              Mikulas_Dzurinda       1.00      0.70      0.82        10
#                Morgan_Freeman       1.00      0.40      0.57        10
#                   Nancy_Demme       1.00      0.80      0.89        10
#                   Nathan_Lane       1.00      0.60      0.75        10
#                  Nicholas_Tse       1.00      0.20      0.33        10
#                Nicolas_Escude       1.00      1.00      1.00        10
#          Nursultan_Nazarbayev       1.00      0.70      0.82        10
#                     Pat_Burns       1.00      0.90      0.95        10
#                       Pat_Cox       1.00      1.00      1.00        10
#                 Patrick_Ewing       1.00      0.70      0.82        10
#                Peter_Costello       1.00      1.00      1.00        10
#               Peter_Greenaway       1.00      0.80      0.89        10
#                Phil_Mickelson       0.05      0.60      0.09        10
#               Philippe_Noiret       1.00      0.50      0.67        10
#               Princess_Masako       1.00      0.70      0.82        10
#                   Ralph_Klein       1.00      0.80      0.89        10
#          Ricardo_Lopez_Murphy       1.00      1.00      1.00        10
#                 Richard_Haass       1.00      0.80      0.89        10
#              Richard_Sambrook       1.00      0.70      0.82        10
#                  Ricky_Martin       0.70      0.70      0.70        10
#              Robert_Blackwill       1.00      0.60      0.75        10
#                   Robert_Fico       1.00      0.60      0.75        10
#                 Robert_Mugabe       1.00      0.80      0.89        10
#               Rod_Blagojevich       1.00      1.00      1.00        10
#                Rogerio_Romero       0.89      0.80      0.84        10
#                  Scott_Ritter       1.00      0.80      0.89        10
#              Silvio_Fernandez       1.00      0.30      0.46        10
#                Stephen_Daldry       1.00      0.40      0.57        10
#              Stephen_Friedman       1.00      0.50      0.67        10
#                 Terrell_Suggs       1.00      0.40      0.57        10
#                Thomas_Malchow       1.00      0.70      0.82        10
#                     Tom_Jones       1.00      0.50      0.67        10
#                 Tracy_McGrady       1.00      0.70      0.82        10
#                    Tyra_Banks       1.00      0.90      0.95        10
#                  Vaclav_Klaus       1.00      0.10      0.18        10
#                  Wesley_Clark       1.00      0.50      0.67        10
#                  Yossi_Beilin       1.00      0.80      0.89        10
#                  Yuri_Fedotov       1.00      0.80      0.89        10
#
#                      accuracy                           0.67      1000
#                     macro avg       0.95      0.67      0.76      1000
#                  weighted avg       0.95      0.67      0.76      1000
# {'accuracy': 0.673,
#  'precision': 0.9451809873936879,
#  'recall': 0.6729999999999998,
#  'f1_score': 0.7559157250301116}

# %%
evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - ArcFace Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="ArcFace",
    enforce_detection=False,
)
# Out:
# DeepFace - ArcFace Multi-class Face Recognition (One ORI vs. AUG)
# =================================================================
# Accuracy : 0.6480
# Precision: 0.9207
# Recall   : 0.6480
# F1-score : 0.7319
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       0.80      0.40      0.53        10
#                   Bill_Nelson       1.00      0.90      0.95        10
#              Boris_Berezovsky       1.00      0.50      0.67        10
#                   Brian_Cowen       1.00      0.70      0.82        10
#                    Cesar_Maia       0.57      0.40      0.47        10
#               Charles_Kartman       1.00      0.60      0.75        10
#               Charles_Schumer       1.00      0.60      0.75        10
#                 Chen_Liang_Yu       1.00      0.90      0.95        10
#                  Chris_Tucker       1.00      0.40      0.57        10
#                   Chuck_Amato       1.00      0.70      0.82        10
#                Chung_Mong-hun       0.02      0.10      0.04        10
#                   David_Spade       1.00      0.70      0.82        10
#                Denise_Johnson       1.00      0.30      0.46        10
#               Dennis_Erickson       1.00      0.80      0.89        10
#                 Dennis_Powell       1.00      0.80      0.89        10
#                 Dolma_Tsering       1.00      0.60      0.75        10
#                   Doug_Duncan       1.00      0.70      0.82        10
#                   Eddy_Merckx       1.00      0.60      0.75        10
#              Elizabeth_Taylor       1.00      0.30      0.46        10
#               Ellen_DeGeneres       1.00      0.60      0.75        10
#                  Emile_Lahoud       0.27      0.70      0.39        10
#             Erika_Christensen       1.00      0.80      0.89        10
#             Evander_Holyfield       1.00      0.60      0.75        10
#                Francis_George       1.00      0.50      0.67        10
#                Garry_Kasparov       1.00      0.80      0.89        10
#                   Gary_Forsee       1.00      0.40      0.57        10
#                 Gary_Williams       1.00      0.40      0.57        10
#                  Gary_Winnick       1.00      0.60      0.75        10
#               George_Roy_Hill       1.00      0.60      0.75        10
#              Gerard_Depardieu       1.00      0.40      0.57        10
#                 Gregory_Hines       1.00      0.80      0.89        10
#                 Hanan_Ashrawi       1.00      0.80      0.89        10
#                 Hideki_Matsui       1.00      0.70      0.82        10
#                Hootie_Johnson       0.05      0.70      0.09        10
#                  Howard_Smith       1.00      0.50      0.67        10
#                     Iban_Mayo       1.00      0.70      0.82        10
#                    Iva_Majoli       0.06      0.40      0.11        10
#           Jacqueline_Obradors       1.00      0.90      0.95        10
#            Jada_Pinkett_Smith       1.00      0.60      0.75        10
#                 James_Schultz       1.00      0.80      0.89        10
#           Jean-Claude_Juncker       1.00      0.60      0.75        10
#         Jeffrey_Scott_Postell       1.00      0.80      0.89        10
#             Jennifer_Thompson       1.00      0.70      0.82        10
#                 Jerry_Falwell       1.00      0.90      0.95        10
#                  John_Spencer       1.00      0.70      0.82        10
# Jorge_Rodolfo_Canicoba_Corral       1.00      0.60      0.75        10
#                    Judi_Dench       1.00      0.80      0.89        10
#                 Justin_Gatlin       1.00      0.70      0.82        10
#                 Kathy_Winters       1.00      0.90      0.95        10
#                 Kenneth_Evans       1.00      0.60      0.75        10
#            Kieran_Prendergast       1.00      0.70      0.82        10
#                  Kurt_Russell       1.00      0.80      0.89        10
#             Lawrence_MacAulay       1.00      1.00      1.00        10
#                       Lee_Jun       0.89      0.80      0.84        10
#                Leland_Chapman       1.00      0.60      0.75        10
#                 Lindsay_Benko       1.00      0.50      0.67        10
#                Marilyn_Monroe       1.00      0.40      0.57        10
#                    Mark_Cuban       1.00      0.70      0.82        10
#                 Mark_Hamister       0.88      0.70      0.78        10
#              Miguel_Contreras       0.12      0.70      0.21        10
#             Mikhail_Gorbachev       1.00      0.80      0.89        10
#              Mikulas_Dzurinda       1.00      0.70      0.82        10
#                Morgan_Freeman       0.50      0.40      0.44        10
#                   Nancy_Demme       1.00      0.80      0.89        10
#                   Nathan_Lane       1.00      0.70      0.82        10
#                  Nicholas_Tse       1.00      0.20      0.33        10
#                Nicolas_Escude       1.00      0.90      0.95        10
#          Nursultan_Nazarbayev       0.70      0.70      0.70        10
#                     Pat_Burns       1.00      0.50      0.67        10
#                       Pat_Cox       1.00      0.90      0.95        10
#                 Patrick_Ewing       1.00      0.90      0.95        10
#                Peter_Costello       1.00      1.00      1.00        10
#               Peter_Greenaway       0.80      0.80      0.80        10
#                Phil_Mickelson       0.10      0.30      0.15        10
#               Philippe_Noiret       1.00      0.60      0.75        10
#               Princess_Masako       1.00      0.50      0.67        10
#                   Ralph_Klein       1.00      0.80      0.89        10
#          Ricardo_Lopez_Murphy       1.00      1.00      1.00        10
#                 Richard_Haass       1.00      0.70      0.82        10
#              Richard_Sambrook       1.00      0.70      0.82        10
#                  Ricky_Martin       1.00      0.70      0.82        10
#              Robert_Blackwill       1.00      0.60      0.75        10
#                   Robert_Fico       1.00      0.50      0.67        10
#                 Robert_Mugabe       1.00      0.80      0.89        10
#               Rod_Blagojevich       1.00      1.00      1.00        10
#                Rogerio_Romero       1.00      0.80      0.89        10
#                  Scott_Ritter       1.00      0.90      0.95        10
#              Silvio_Fernandez       0.50      0.30      0.38        10
#                Stephen_Daldry       1.00      0.40      0.57        10
#              Stephen_Friedman       0.80      0.40      0.53        10
#                 Terrell_Suggs       1.00      0.90      0.95        10
#                Thomas_Malchow       1.00      0.70      0.82        10
#                     Tom_Jones       1.00      0.60      0.75        10
#                 Tracy_McGrady       1.00      0.40      0.57        10
#                    Tyra_Banks       1.00      0.80      0.89        10
#                  Vaclav_Klaus       1.00      0.10      0.18        10
#                  Wesley_Clark       1.00      0.40      0.57        10
#                  Yossi_Beilin       1.00      0.80      0.89        10
#                  Yuri_Fedotov       1.00      0.30      0.46        10
#
#                      accuracy                           0.65      1000
#                     macro avg       0.92      0.65      0.73      1000
#                  weighted avg       0.92      0.65      0.73      1000
# {'accuracy': 0.648,
#  'precision': 0.9206512567891879,
#  'recall': 0.648,
#  'f1_score': 0.7318862310805316}

# %%
evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - SFace Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="SFace",
    enforce_detection=False,
)
# Out:
# DeepFace - SFace Multi-class Face Recognition (One ORI vs. AUG)
# ===============================================================
# Accuracy : 0.6090
# Precision: 0.9376
# Recall   : 0.6090
# F1-score : 0.7084
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       1.00      0.50      0.67        10
#                   Bill_Nelson       1.00      0.80      0.89        10
#              Boris_Berezovsky       1.00      0.40      0.57        10
#                   Brian_Cowen       0.78      0.70      0.74        10
#                    Cesar_Maia       1.00      0.30      0.46        10
#               Charles_Kartman       1.00      0.50      0.67        10
#               Charles_Schumer       1.00      0.60      0.75        10
#                 Chen_Liang_Yu       1.00      0.80      0.89        10
#                  Chris_Tucker       1.00      0.40      0.57        10
#                   Chuck_Amato       1.00      0.80      0.89        10
#                Chung_Mong-hun       0.16      0.40      0.23        10
#                   David_Spade       1.00      0.60      0.75        10
#                Denise_Johnson       1.00      0.30      0.46        10
#               Dennis_Erickson       1.00      0.90      0.95        10
#                 Dennis_Powell       1.00      0.80      0.89        10
#                 Dolma_Tsering       0.60      0.60      0.60        10
#                   Doug_Duncan       1.00      0.80      0.89        10
#                   Eddy_Merckx       1.00      0.60      0.75        10
#              Elizabeth_Taylor       1.00      0.30      0.46        10
#               Ellen_DeGeneres       1.00      0.20      0.33        10
#                  Emile_Lahoud       1.00      0.50      0.67        10
#             Erika_Christensen       1.00      0.80      0.89        10
#             Evander_Holyfield       1.00      0.60      0.75        10
#                Francis_George       0.67      0.60      0.63        10
#                Garry_Kasparov       1.00      0.70      0.82        10
#                   Gary_Forsee       1.00      0.40      0.57        10
#                 Gary_Williams       1.00      0.50      0.67        10
#                  Gary_Winnick       1.00      0.60      0.75        10
#               George_Roy_Hill       1.00      0.60      0.75        10
#              Gerard_Depardieu       1.00      0.40      0.57        10
#                 Gregory_Hines       1.00      0.80      0.89        10
#                 Hanan_Ashrawi       1.00      0.80      0.89        10
#                 Hideki_Matsui       1.00      0.30      0.46        10
#                Hootie_Johnson       0.22      0.40      0.29        10
#                  Howard_Smith       1.00      0.50      0.67        10
#                     Iban_Mayo       1.00      0.40      0.57        10
#                    Iva_Majoli       0.27      0.40      0.32        10
#           Jacqueline_Obradors       1.00      0.80      0.89        10
#            Jada_Pinkett_Smith       1.00      0.70      0.82        10
#                 James_Schultz       1.00      0.80      0.89        10
#           Jean-Claude_Juncker       1.00      0.50      0.67        10
#         Jeffrey_Scott_Postell       1.00      0.80      0.89        10
#             Jennifer_Thompson       1.00      0.70      0.82        10
#                 Jerry_Falwell       1.00      0.40      0.57        10
#                  John_Spencer       0.88      0.70      0.78        10
# Jorge_Rodolfo_Canicoba_Corral       1.00      0.60      0.75        10
#                    Judi_Dench       1.00      0.70      0.82        10
#                 Justin_Gatlin       1.00      0.60      0.75        10
#                 Kathy_Winters       1.00      0.80      0.89        10
#                 Kenneth_Evans       1.00      0.60      0.75        10
#            Kieran_Prendergast       0.88      0.70      0.78        10
#                  Kurt_Russell       1.00      0.60      0.75        10
#             Lawrence_MacAulay       1.00      0.90      0.95        10
#                       Lee_Jun       1.00      0.80      0.89        10
#                Leland_Chapman       1.00      0.40      0.57        10
#                 Lindsay_Benko       1.00      0.80      0.89        10
#                Marilyn_Monroe       1.00      0.10      0.18        10
#                    Mark_Cuban       1.00      0.70      0.82        10
#                 Mark_Hamister       1.00      0.70      0.82        10
#              Miguel_Contreras       1.00      0.40      0.57        10
#             Mikhail_Gorbachev       1.00      0.70      0.82        10
#              Mikulas_Dzurinda       1.00      0.70      0.82        10
#                Morgan_Freeman       1.00      0.30      0.46        10
#                   Nancy_Demme       0.89      0.80      0.84        10
#                   Nathan_Lane       1.00      0.70      0.82        10
#                  Nicholas_Tse       1.00      0.30      0.46        10
#                Nicolas_Escude       1.00      1.00      1.00        10
#          Nursultan_Nazarbayev       1.00      0.70      0.82        10
#                     Pat_Burns       1.00      0.70      0.82        10
#                       Pat_Cox       1.00      0.60      0.75        10
#                 Patrick_Ewing       1.00      0.90      0.95        10
#                Peter_Costello       1.00      0.40      0.57        10
#               Peter_Greenaway       1.00      0.90      0.95        10
#                Phil_Mickelson       0.03      1.00      0.06        10
#               Philippe_Noiret       1.00      0.50      0.67        10
#               Princess_Masako       1.00      0.70      0.82        10
#                   Ralph_Klein       1.00      0.70      0.82        10
#          Ricardo_Lopez_Murphy       1.00      0.90      0.95        10
#                 Richard_Haass       1.00      0.70      0.82        10
#              Richard_Sambrook       1.00      0.70      0.82        10
#                  Ricky_Martin       1.00      0.30      0.46        10
#              Robert_Blackwill       1.00      0.60      0.75        10
#                   Robert_Fico       1.00      0.40      0.57        10
#                 Robert_Mugabe       1.00      0.80      0.89        10
#               Rod_Blagojevich       1.00      1.00      1.00        10
#                Rogerio_Romero       1.00      0.70      0.82        10
#                  Scott_Ritter       0.73      0.80      0.76        10
#              Silvio_Fernandez       1.00      0.30      0.46        10
#                Stephen_Daldry       1.00      0.40      0.57        10
#              Stephen_Friedman       0.67      0.40      0.50        10
#                 Terrell_Suggs       1.00      0.70      0.82        10
#                Thomas_Malchow       1.00      0.70      0.82        10
#                     Tom_Jones       1.00      0.50      0.67        10
#                 Tracy_McGrady       1.00      0.60      0.75        10
#                    Tyra_Banks       1.00      0.70      0.82        10
#                  Vaclav_Klaus       0.33      0.10      0.15        10
#                  Wesley_Clark       1.00      0.40      0.57        10
#                  Yossi_Beilin       0.67      0.80      0.73        10
#                  Yuri_Fedotov       1.00      0.40      0.57        10
#
#                      accuracy                           0.61      1000
#                     macro avg       0.94      0.61      0.71      1000
#                  weighted avg       0.94      0.61      0.71      1000
# {'accuracy': 0.609,
#  'precision': 0.9375628209808933,
#  'recall': 0.6089999999999999,
#  'f1_score': 0.7083846899230801}
