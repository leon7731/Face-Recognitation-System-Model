# %%
import os
import cv2
import random
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go


from deepface import DeepFace

from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score


from collections import Counter

# %% [markdown]
# # Step 1: Evaluate Deepface Models
#
# - Facenet
# - Facenet512
# - GhostFaceNet
# - ArcFace
# - SFace
# - Dlib

# %%
def evaluate_multiclass_one_ori_against_aug(
    data_dir,
    model_name="Facenet",
    enforce_detection=False,
    title="Multi-class Face Recognition (One ORI vs. AUG)"
):
    """
    Performs multi-class face recognition in a dataset where each subfolder represents a class.
    Each class folder contains multiple images, including at least one 'ori_' image and 
    multiple 'aug_' images.

    1. For each class, pick exactly one 'ori_' image as the reference (enrollment) image.
    2. Compute embeddings for all 'aug_' images across all classes, comparing each to every 
       class's reference embedding (Euclidean distance).
    3. Assign each 'aug_' image to the class with the nearest reference embedding.
    4. Generate a multi-class classification report.
    """

    # 1. Gather all classes and separate 'ori_' from 'aug_' images
    subfolders = [f.path for f in os.scandir(data_dir) if f.is_dir()]

    # We'll store references in a dict: { class_name: embedding_of_one_ori (as a NumPy array) }
    class_reference_embeddings = {}
    # We'll store test images in a list of (img_path, class_name)
    test_images = []

    for subfolder in subfolders:
        class_name = os.path.basename(subfolder)
        all_images = [
            os.path.join(subfolder, img)
            for img in os.listdir(subfolder)
            if img.lower().endswith((".jpg", ".jpeg", ".png"))
        ]

        # Separate ori_ and aug_ images
        ori_imgs = [img for img in all_images if "ori_" in os.path.basename(img)]
        aug_imgs = [img for img in all_images if "aug_" in os.path.basename(img)]

        # Pick exactly one ori_ image as the reference (e.g., the first one if multiple exist)
        if ori_imgs:
            reference_img = ori_imgs[0]  # pick the first
            try:
                rep = DeepFace.represent(
                    reference_img,
                    model_name=model_name,
                    enforce_detection=enforce_detection
                )
                if rep and len(rep) > 0:
                    # Convert the embedding list to a NumPy array
                    emb_array = np.array(rep[0]["embedding"], dtype=np.float32)
                    class_reference_embeddings[class_name] = emb_array
                else:
                    print(f"Warning: No embedding found for {reference_img}. Skipping class '{class_name}'")
                    continue
            except Exception as e:
                print(f"Error generating embedding for {reference_img}: {e}")
                continue
        else:
            # If there's no ori image, skip the class
            print(f"Warning: No 'ori_' image found for class '{class_name}'. Skipping.")
            continue

        # All aug_ images become test images
        for aug_img in aug_imgs:
            test_images.append((aug_img, class_name))

    if not class_reference_embeddings:
        print("No classes with valid reference embeddings found.")
        return {}

    if not test_images:
        print("No test (aug) images found.")
        return {}

    # 2. For each test image, find the class with the nearest reference embedding
    true_labels = []
    pred_labels = []

    for (img_path, true_class) in test_images:
        true_labels.append(true_class)

        try:
            rep = DeepFace.represent(
                img_path,
                model_name=model_name,
                enforce_detection=enforce_detection
            )
            if rep and len(rep) > 0:
                # Convert the embedding list to a NumPy array
                emb = np.array(rep[0]["embedding"], dtype=np.float32)
            else:
                # If no embedding, label as "Unknown"
                pred_labels.append("Unknown")
                continue
        except Exception as e:
            print(f"Error generating embedding for {img_path}: {e}")
            pred_labels.append("Unknown")
            continue

        # Compute Euclidean distance to each class reference
        best_class = None
        best_dist = float("inf")
        for c_name, c_emb in class_reference_embeddings.items():
            # Now c_emb and emb are both NumPy arrays, so subtraction works
            dist = np.linalg.norm(emb - c_emb)
            if dist < best_dist:
                best_dist = dist
                best_class = c_name

        if best_class is not None:
            pred_labels.append(best_class)
        else:
            pred_labels.append("Unknown")

    # 3. Compute multi-class metrics
    all_classes = sorted(class_reference_embeddings.keys())
    # If "Unknown" is in predictions, optionally add it to the label set
    if "Unknown" in pred_labels:
        all_classes += ["Unknown"]

    accuracy = accuracy_score(true_labels, pred_labels)
    precision = precision_score(true_labels, pred_labels, average="macro", zero_division=0)
    recall = recall_score(true_labels, pred_labels, average="macro", zero_division=0)
    f1 = f1_score(true_labels, pred_labels, average="macro", zero_division=0)

    print(title)
    print("=" * len(title))
    print(f"Accuracy : {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall   : {recall:.4f}")
    print(f"F1-score : {f1:.4f}\n")

    # Print full classification report
    from sklearn.metrics import classification_report
    report = classification_report(true_labels, pred_labels, labels=all_classes, zero_division=0)
    print("Full Classification Report:")
    print(report)

    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }

# %%
test_data_dir = "lfw-deepfunneled-augmentedV1-test" # Test dataset directory

evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - Facenet Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="Facenet",
    enforce_detection=False,
)
# Out:
# DeepFace - Facenet Multi-class Face Recognition (One ORI vs. AUG)
# =================================================================
# Accuracy : 0.8780
# Precision: 0.9371
# Recall   : 0.8780
# F1-score : 0.8887
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       0.56      0.50      0.53        10
#                   Bill_Nelson       1.00      1.00      1.00        10
#              Boris_Berezovsky       1.00      1.00      1.00        10
#                   Brian_Cowen       1.00      1.00      1.00        10
#                    Cesar_Maia       1.00      0.90      0.95        10
#               Charles_Kartman       1.00      1.00      1.00        10
#               Charles_Schumer       1.00      0.80      0.89        10
#                 Chen_Liang_Yu       1.00      1.00      1.00        10
#                  Chris_Tucker       1.00      1.00      1.00        10
#                   Chuck_Amato       1.00      1.00      1.00        10
#                Chung_Mong-hun       0.62      0.50      0.56        10
#                   David_Spade       1.00      0.70      0.82        10
#                Denise_Johnson       1.00      0.50      0.67        10
#               Dennis_Erickson       1.00      1.00      1.00        10
#                 Dennis_Powell       0.71      1.00      0.83        10
#                 Dolma_Tsering       1.00      1.00      1.00        10
#                   Doug_Duncan       1.00      1.00      1.00        10
#                   Eddy_Merckx       1.00      1.00      1.00        10
#              Elizabeth_Taylor       1.00      0.50      0.67        10
#               Ellen_DeGeneres       1.00      1.00      1.00        10
#                  Emile_Lahoud       1.00      0.70      0.82        10
#             Erika_Christensen       1.00      1.00      1.00        10
#             Evander_Holyfield       1.00      1.00      1.00        10
#                Francis_George       1.00      1.00      1.00        10
#                Garry_Kasparov       1.00      1.00      1.00        10
#                   Gary_Forsee       1.00      0.80      0.89        10
#                 Gary_Williams       1.00      0.50      0.67        10
#                  Gary_Winnick       1.00      1.00      1.00        10
#               George_Roy_Hill       1.00      1.00      1.00        10
#              Gerard_Depardieu       1.00      1.00      1.00        10
#                 Gregory_Hines       1.00      1.00      1.00        10
#                 Hanan_Ashrawi       1.00      1.00      1.00        10
#                 Hideki_Matsui       1.00      0.90      0.95        10
#                Hootie_Johnson       0.30      0.30      0.30        10
#                  Howard_Smith       0.83      0.50      0.62        10
#                     Iban_Mayo       1.00      1.00      1.00        10
#                    Iva_Majoli       0.25      0.90      0.39        10
#           Jacqueline_Obradors       1.00      1.00      1.00        10
#            Jada_Pinkett_Smith       1.00      1.00      1.00        10
#                 James_Schultz       1.00      1.00      1.00        10
#           Jean-Claude_Juncker       1.00      1.00      1.00        10
#         Jeffrey_Scott_Postell       1.00      1.00      1.00        10
#             Jennifer_Thompson       0.77      1.00      0.87        10
#                 Jerry_Falwell       1.00      0.50      0.67        10
#                  John_Spencer       1.00      1.00      1.00        10
# Jorge_Rodolfo_Canicoba_Corral       1.00      1.00      1.00        10
#                    Judi_Dench       1.00      1.00      1.00        10
#                 Justin_Gatlin       1.00      1.00      1.00        10
#                 Kathy_Winters       0.91      1.00      0.95        10
#                 Kenneth_Evans       0.78      0.70      0.74        10
#            Kieran_Prendergast       1.00      1.00      1.00        10
#                  Kurt_Russell       1.00      1.00      1.00        10
#             Lawrence_MacAulay       1.00      1.00      1.00        10
#                       Lee_Jun       1.00      1.00      1.00        10
#                Leland_Chapman       1.00      1.00      1.00        10
#                 Lindsay_Benko       1.00      1.00      1.00        10
#                Marilyn_Monroe       1.00      1.00      1.00        10
#                    Mark_Cuban       1.00      1.00      1.00        10
#                 Mark_Hamister       1.00      1.00      1.00        10
#              Miguel_Contreras       0.28      0.50      0.36        10
#             Mikhail_Gorbachev       0.77      1.00      0.87        10
#              Mikulas_Dzurinda       1.00      1.00      1.00        10
#                Morgan_Freeman       1.00      0.60      0.75        10
#                   Nancy_Demme       1.00      1.00      1.00        10
#                   Nathan_Lane       1.00      0.50      0.67        10
#                  Nicholas_Tse       1.00      1.00      1.00        10
#                Nicolas_Escude       1.00      1.00      1.00        10
#          Nursultan_Nazarbayev       1.00      1.00      1.00        10
#                     Pat_Burns       1.00      1.00      1.00        10
#                       Pat_Cox       0.40      1.00      0.57        10
#                 Patrick_Ewing       1.00      0.80      0.89        10
#                Peter_Costello       1.00      0.50      0.67        10
#               Peter_Greenaway       1.00      1.00      1.00        10
#                Phil_Mickelson       0.16      0.50      0.24        10
#               Philippe_Noiret       1.00      0.50      0.67        10
#               Princess_Masako       1.00      1.00      1.00        10
#                   Ralph_Klein       1.00      1.00      1.00        10
#          Ricardo_Lopez_Murphy       1.00      1.00      1.00        10
#                 Richard_Haass       1.00      1.00      1.00        10
#              Richard_Sambrook       1.00      1.00      1.00        10
#                  Ricky_Martin       1.00      0.50      0.67        10
#              Robert_Blackwill       1.00      1.00      1.00        10
#                   Robert_Fico       1.00      0.80      0.89        10
#                 Robert_Mugabe       1.00      1.00      1.00        10
#               Rod_Blagojevich       1.00      1.00      1.00        10
#                Rogerio_Romero       1.00      1.00      1.00        10
#                  Scott_Ritter       1.00      1.00      1.00        10
#              Silvio_Fernandez       1.00      0.50      0.67        10
#                Stephen_Daldry       1.00      0.50      0.67        10
#              Stephen_Friedman       1.00      0.50      0.67        10
#                 Terrell_Suggs       0.91      1.00      0.95        10
#                Thomas_Malchow       1.00      1.00      1.00        10
#                     Tom_Jones       1.00      0.50      0.67        10
#                 Tracy_McGrady       1.00      0.90      0.95        10
#                    Tyra_Banks       1.00      1.00      1.00        10
#                  Vaclav_Klaus       1.00      0.50      0.67        10
#                  Wesley_Clark       1.00      1.00      1.00        10
#                  Yossi_Beilin       0.45      1.00      0.62        10
#                  Yuri_Fedotov       1.00      1.00      1.00        10
#
#                      accuracy                           0.88      1000
#                     macro avg       0.94      0.88      0.89      1000
#                  weighted avg       0.94      0.88      0.89      1000
# {'accuracy': 0.878,
#  'precision': 0.9370620929249961,
#  'recall': 0.878,
#  'f1_score': 0.8887110364750167}

# %%
evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - Facenet512 Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="Facenet512",
    enforce_detection=False,
)
# Out:
# DeepFace - Facenet512 Multi-class Face Recognition (One ORI vs. AUG)
# ====================================================================
# Accuracy : 0.9110
# Precision: 0.9352
# Recall   : 0.9110
# F1-score : 0.9101
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       0.71      0.50      0.59        10
#                   Bill_Nelson       1.00      1.00      1.00        10
#              Boris_Berezovsky       1.00      1.00      1.00        10
#                   Brian_Cowen       1.00      1.00      1.00        10
#                    Cesar_Maia       1.00      0.90      0.95        10
#               Charles_Kartman       0.67      1.00      0.80        10
#               Charles_Schumer       1.00      0.80      0.89        10
#                 Chen_Liang_Yu       1.00      1.00      1.00        10
#                  Chris_Tucker       0.77      1.00      0.87        10
#                   Chuck_Amato       1.00      1.00      1.00        10
#                Chung_Mong-hun       1.00      0.50      0.67        10
#                   David_Spade       1.00      1.00      1.00        10
#                Denise_Johnson       1.00      1.00      1.00        10
#               Dennis_Erickson       1.00      1.00      1.00        10
#                 Dennis_Powell       1.00      1.00      1.00        10
#                 Dolma_Tsering       0.77      1.00      0.87        10
#                   Doug_Duncan       1.00      1.00      1.00        10
#                   Eddy_Merckx       0.83      1.00      0.91        10
#              Elizabeth_Taylor       1.00      0.50      0.67        10
#               Ellen_DeGeneres       1.00      1.00      1.00        10
#                  Emile_Lahoud       1.00      1.00      1.00        10
#             Erika_Christensen       1.00      1.00      1.00        10
#             Evander_Holyfield       1.00      1.00      1.00        10
#                Francis_George       1.00      1.00      1.00        10
#                Garry_Kasparov       1.00      1.00      1.00        10
#                   Gary_Forsee       1.00      1.00      1.00        10
#                 Gary_Williams       1.00      0.70      0.82        10
#                  Gary_Winnick       1.00      1.00      1.00        10
#               George_Roy_Hill       1.00      1.00      1.00        10
#              Gerard_Depardieu       1.00      1.00      1.00        10
#                 Gregory_Hines       1.00      1.00      1.00        10
#                 Hanan_Ashrawi       1.00      1.00      1.00        10
#                 Hideki_Matsui       1.00      1.00      1.00        10
#                Hootie_Johnson       0.33      0.50      0.40        10
#                  Howard_Smith       1.00      0.70      0.82        10
#                     Iban_Mayo       1.00      1.00      1.00        10
#                    Iva_Majoli       1.00      1.00      1.00        10
#           Jacqueline_Obradors       1.00      1.00      1.00        10
#            Jada_Pinkett_Smith       1.00      1.00      1.00        10
#                 James_Schultz       0.83      1.00      0.91        10
#           Jean-Claude_Juncker       0.67      1.00      0.80        10
#         Jeffrey_Scott_Postell       1.00      1.00      1.00        10
#             Jennifer_Thompson       1.00      1.00      1.00        10
#                 Jerry_Falwell       0.50      0.50      0.50        10
#                  John_Spencer       1.00      1.00      1.00        10
# Jorge_Rodolfo_Canicoba_Corral       1.00      1.00      1.00        10
#                    Judi_Dench       0.77      1.00      0.87        10
#                 Justin_Gatlin       0.71      1.00      0.83        10
#                 Kathy_Winters       1.00      1.00      1.00        10
#                 Kenneth_Evans       0.78      0.70      0.74        10
#            Kieran_Prendergast       1.00      1.00      1.00        10
#                  Kurt_Russell       1.00      1.00      1.00        10
#             Lawrence_MacAulay       1.00      1.00      1.00        10
#                       Lee_Jun       1.00      1.00      1.00        10
#                Leland_Chapman       1.00      1.00      1.00        10
#                 Lindsay_Benko       1.00      1.00      1.00        10
#                Marilyn_Monroe       1.00      0.50      0.67        10
#                    Mark_Cuban       1.00      1.00      1.00        10
#                 Mark_Hamister       0.67      1.00      0.80        10
#              Miguel_Contreras       1.00      0.50      0.67        10
#             Mikhail_Gorbachev       0.67      1.00      0.80        10
#              Mikulas_Dzurinda       1.00      1.00      1.00        10
#                Morgan_Freeman       1.00      1.00      1.00        10
#                   Nancy_Demme       1.00      1.00      1.00        10
#                   Nathan_Lane       1.00      1.00      1.00        10
#                  Nicholas_Tse       0.71      1.00      0.83        10
#                Nicolas_Escude       1.00      1.00      1.00        10
#          Nursultan_Nazarbayev       1.00      1.00      1.00        10
#                     Pat_Burns       1.00      1.00      1.00        10
#                       Pat_Cox       1.00      1.00      1.00        10
#                 Patrick_Ewing       1.00      0.50      0.67        10
#                Peter_Costello       1.00      0.60      0.75        10
#               Peter_Greenaway       1.00      1.00      1.00        10
#                Phil_Mickelson       0.25      0.50      0.33        10
#               Philippe_Noiret       1.00      0.50      0.67        10
#               Princess_Masako       1.00      1.00      1.00        10
#                   Ralph_Klein       1.00      1.00      1.00        10
#          Ricardo_Lopez_Murphy       1.00      1.00      1.00        10
#                 Richard_Haass       0.77      1.00      0.87        10
#              Richard_Sambrook       0.77      1.00      0.87        10
#                  Ricky_Martin       1.00      1.00      1.00        10
#              Robert_Blackwill       0.77      1.00      0.87        10
#                   Robert_Fico       0.89      0.80      0.84        10
#                 Robert_Mugabe       1.00      1.00      1.00        10
#               Rod_Blagojevich       1.00      1.00      1.00        10
#                Rogerio_Romero       1.00      1.00      1.00        10
#                  Scott_Ritter       1.00      1.00      1.00        10
#              Silvio_Fernandez       1.00      0.60      0.75        10
#                Stephen_Daldry       1.00      0.50      0.67        10
#              Stephen_Friedman       1.00      0.70      0.82        10
#                 Terrell_Suggs       1.00      0.60      0.75        10
#                Thomas_Malchow       1.00      1.00      1.00        10
#                     Tom_Jones       1.00      1.00      1.00        10
#                 Tracy_McGrady       1.00      1.00      1.00        10
#                    Tyra_Banks       1.00      1.00      1.00        10
#                  Vaclav_Klaus       1.00      0.50      0.67        10
#                  Wesley_Clark       0.91      1.00      0.95        10
#                  Yossi_Beilin       1.00      1.00      1.00        10
#                  Yuri_Fedotov       0.77      1.00      0.87        10
#
#                      accuracy                           0.91      1000
#                     macro avg       0.94      0.91      0.91      1000
#                  weighted avg       0.94      0.91      0.91      1000
# {'accuracy': 0.911,
#  'precision': 0.9351989676989677,
#  'recall': 0.9109999999999999,
#  'f1_score': 0.9101488083340956}

# %%
evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - GhostFaceNet Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="GhostFaceNet",
    enforce_detection=False,
)
# Out:
# DeepFace - GhostFaceNet Multi-class Face Recognition (One ORI vs. AUG)
# ======================================================================
# Accuracy : 0.9200
# Precision: 0.9663
# Recall   : 0.9200
# F1-score : 0.9303
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       1.00      1.00      1.00        10
#                   Bill_Nelson       1.00      1.00      1.00        10
#              Boris_Berezovsky       1.00      1.00      1.00        10
#                   Brian_Cowen       1.00      1.00      1.00        10
#                    Cesar_Maia       1.00      0.90      0.95        10
#               Charles_Kartman       1.00      1.00      1.00        10
#               Charles_Schumer       1.00      0.80      0.89        10
#                 Chen_Liang_Yu       1.00      1.00      1.00        10
#                  Chris_Tucker       1.00      1.00      1.00        10
#                   Chuck_Amato       1.00      1.00      1.00        10
#                Chung_Mong-hun       0.29      0.80      0.42        10
#                   David_Spade       1.00      1.00      1.00        10
#                Denise_Johnson       1.00      0.50      0.67        10
#               Dennis_Erickson       1.00      1.00      1.00        10
#                 Dennis_Powell       1.00      1.00      1.00        10
#                 Dolma_Tsering       0.83      1.00      0.91        10
#                   Doug_Duncan       1.00      1.00      1.00        10
#                   Eddy_Merckx       1.00      1.00      1.00        10
#              Elizabeth_Taylor       1.00      0.50      0.67        10
#               Ellen_DeGeneres       0.91      1.00      0.95        10
#                  Emile_Lahoud       1.00      0.50      0.67        10
#             Erika_Christensen       0.71      1.00      0.83        10
#             Evander_Holyfield       1.00      1.00      1.00        10
#                Francis_George       1.00      1.00      1.00        10
#                Garry_Kasparov       1.00      1.00      1.00        10
#                   Gary_Forsee       1.00      1.00      1.00        10
#                 Gary_Williams       1.00      1.00      1.00        10
#                  Gary_Winnick       1.00      1.00      1.00        10
#               George_Roy_Hill       1.00      1.00      1.00        10
#              Gerard_Depardieu       1.00      1.00      1.00        10
#                 Gregory_Hines       1.00      1.00      1.00        10
#                 Hanan_Ashrawi       1.00      1.00      1.00        10
#                 Hideki_Matsui       1.00      0.90      0.95        10
#                Hootie_Johnson       0.15      0.60      0.24        10
#                  Howard_Smith       1.00      1.00      1.00        10
#                     Iban_Mayo       1.00      1.00      1.00        10
#                    Iva_Majoli       0.56      0.50      0.53        10
#           Jacqueline_Obradors       1.00      1.00      1.00        10
#            Jada_Pinkett_Smith       1.00      1.00      1.00        10
#                 James_Schultz       1.00      1.00      1.00        10
#           Jean-Claude_Juncker       1.00      1.00      1.00        10
#         Jeffrey_Scott_Postell       1.00      1.00      1.00        10
#             Jennifer_Thompson       1.00      1.00      1.00        10
#                 Jerry_Falwell       1.00      1.00      1.00        10
#                  John_Spencer       1.00      1.00      1.00        10
# Jorge_Rodolfo_Canicoba_Corral       1.00      1.00      1.00        10
#                    Judi_Dench       1.00      1.00      1.00        10
#                 Justin_Gatlin       1.00      0.50      0.67        10
#                 Kathy_Winters       1.00      1.00      1.00        10
#                 Kenneth_Evans       1.00      0.70      0.82        10
#            Kieran_Prendergast       1.00      1.00      1.00        10
#                  Kurt_Russell       1.00      1.00      1.00        10
#             Lawrence_MacAulay       0.83      1.00      0.91        10
#                       Lee_Jun       1.00      1.00      1.00        10
#                Leland_Chapman       1.00      1.00      1.00        10
#                 Lindsay_Benko       1.00      1.00      1.00        10
#                Marilyn_Monroe       1.00      0.60      0.75        10
#                    Mark_Cuban       1.00      1.00      1.00        10
#                 Mark_Hamister       1.00      1.00      1.00        10
#              Miguel_Contreras       1.00      1.00      1.00        10
#             Mikhail_Gorbachev       1.00      1.00      1.00        10
#              Mikulas_Dzurinda       1.00      1.00      1.00        10
#                Morgan_Freeman       1.00      0.50      0.67        10
#                   Nancy_Demme       1.00      1.00      1.00        10
#                   Nathan_Lane       1.00      0.80      0.89        10
#                  Nicholas_Tse       1.00      0.50      0.67        10
#                Nicolas_Escude       1.00      1.00      1.00        10
#          Nursultan_Nazarbayev       1.00      1.00      1.00        10
#                     Pat_Burns       1.00      1.00      1.00        10
#                       Pat_Cox       1.00      1.00      1.00        10
#                 Patrick_Ewing       1.00      0.80      0.89        10
#                Peter_Costello       1.00      1.00      1.00        10
#               Peter_Greenaway       1.00      1.00      1.00        10
#                Phil_Mickelson       0.35      0.70      0.47        10
#               Philippe_Noiret       1.00      0.50      0.67        10
#               Princess_Masako       1.00      1.00      1.00        10
#                   Ralph_Klein       1.00      1.00      1.00        10
#          Ricardo_Lopez_Murphy       1.00      1.00      1.00        10
#                 Richard_Haass       1.00      1.00      1.00        10
#              Richard_Sambrook       1.00      1.00      1.00        10
#                  Ricky_Martin       1.00      1.00      1.00        10
#              Robert_Blackwill       1.00      1.00      1.00        10
#                   Robert_Fico       1.00      0.80      0.89        10
#                 Robert_Mugabe       1.00      1.00      1.00        10
#               Rod_Blagojevich       1.00      1.00      1.00        10
#                Rogerio_Romero       1.00      1.00      1.00        10
#                  Scott_Ritter       1.00      1.00      1.00        10
#              Silvio_Fernandez       1.00      1.00      1.00        10
#                Stephen_Daldry       1.00      0.50      0.67        10
#              Stephen_Friedman       1.00      1.00      1.00        10
#                 Terrell_Suggs       1.00      0.60      0.75        10
#                Thomas_Malchow       1.00      1.00      1.00        10
#                     Tom_Jones       1.00      1.00      1.00        10
#                 Tracy_McGrady       1.00      1.00      1.00        10
#                    Tyra_Banks       1.00      1.00      1.00        10
#                  Vaclav_Klaus       1.00      0.50      0.67        10
#                  Wesley_Clark       1.00      1.00      1.00        10
#                  Yossi_Beilin       1.00      1.00      1.00        10
#                  Yuri_Fedotov       1.00      1.00      1.00        10
#
#                      accuracy                           0.92      1000
#                     macro avg       0.97      0.92      0.93      1000
#                  weighted avg       0.97      0.92      0.93      1000
# {'accuracy': 0.92,
#  'precision': 0.9663131313131313,
#  'recall': 0.92,
#  'f1_score': 0.9303175300104093}

# %%
evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - ArcFace Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="ArcFace",
    enforce_detection=False,
)
# Out:
# DeepFace - ArcFace Multi-class Face Recognition (One ORI vs. AUG)
# =================================================================
# Accuracy : 0.8920
# Precision: 0.9389
# Recall   : 0.8920
# F1-score : 0.9019
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       0.73      0.80      0.76        10
#                   Bill_Nelson       1.00      1.00      1.00        10
#              Boris_Berezovsky       1.00      1.00      1.00        10
#                   Brian_Cowen       1.00      1.00      1.00        10
#                    Cesar_Maia       0.56      0.50      0.53        10
#               Charles_Kartman       1.00      1.00      1.00        10
#               Charles_Schumer       1.00      0.80      0.89        10
#                 Chen_Liang_Yu       1.00      1.00      1.00        10
#                  Chris_Tucker       1.00      0.80      0.89        10
#                   Chuck_Amato       1.00      1.00      1.00        10
#                Chung_Mong-hun       0.14      0.20      0.17        10
#                   David_Spade       1.00      1.00      1.00        10
#                Denise_Johnson       1.00      0.50      0.67        10
#               Dennis_Erickson       1.00      1.00      1.00        10
#                 Dennis_Powell       1.00      1.00      1.00        10
#                 Dolma_Tsering       1.00      1.00      1.00        10
#                   Doug_Duncan       1.00      1.00      1.00        10
#                   Eddy_Merckx       1.00      1.00      1.00        10
#              Elizabeth_Taylor       1.00      0.50      0.67        10
#               Ellen_DeGeneres       1.00      1.00      1.00        10
#                  Emile_Lahoud       0.24      0.80      0.37        10
#             Erika_Christensen       1.00      1.00      1.00        10
#             Evander_Holyfield       1.00      1.00      1.00        10
#                Francis_George       1.00      1.00      1.00        10
#                Garry_Kasparov       1.00      0.70      0.82        10
#                   Gary_Forsee       1.00      1.00      1.00        10
#                 Gary_Williams       1.00      0.60      0.75        10
#                  Gary_Winnick       1.00      1.00      1.00        10
#               George_Roy_Hill       1.00      1.00      1.00        10
#              Gerard_Depardieu       1.00      1.00      1.00        10
#                 Gregory_Hines       1.00      1.00      1.00        10
#                 Hanan_Ashrawi       1.00      1.00      1.00        10
#                 Hideki_Matsui       1.00      0.90      0.95        10
#                Hootie_Johnson       0.33      0.40      0.36        10
#                  Howard_Smith       1.00      0.50      0.67        10
#                     Iban_Mayo       1.00      1.00      1.00        10
#                    Iva_Majoli       0.62      0.50      0.56        10
#           Jacqueline_Obradors       1.00      1.00      1.00        10
#            Jada_Pinkett_Smith       1.00      1.00      1.00        10
#                 James_Schultz       1.00      1.00      1.00        10
#           Jean-Claude_Juncker       1.00      1.00      1.00        10
#         Jeffrey_Scott_Postell       1.00      1.00      1.00        10
#             Jennifer_Thompson       1.00      1.00      1.00        10
#                 Jerry_Falwell       1.00      1.00      1.00        10
#                  John_Spencer       1.00      1.00      1.00        10
# Jorge_Rodolfo_Canicoba_Corral       1.00      1.00      1.00        10
#                    Judi_Dench       1.00      1.00      1.00        10
#                 Justin_Gatlin       1.00      1.00      1.00        10
#                 Kathy_Winters       1.00      1.00      1.00        10
#                 Kenneth_Evans       1.00      0.70      0.82        10
#            Kieran_Prendergast       1.00      1.00      1.00        10
#                  Kurt_Russell       1.00      1.00      1.00        10
#             Lawrence_MacAulay       1.00      1.00      1.00        10
#                       Lee_Jun       1.00      1.00      1.00        10
#                Leland_Chapman       1.00      1.00      1.00        10
#                 Lindsay_Benko       1.00      0.70      0.82        10
#                Marilyn_Monroe       0.91      1.00      0.95        10
#                    Mark_Cuban       1.00      1.00      1.00        10
#                 Mark_Hamister       0.83      1.00      0.91        10
#              Miguel_Contreras       0.23      1.00      0.37        10
#             Mikhail_Gorbachev       1.00      1.00      1.00        10
#              Mikulas_Dzurinda       1.00      1.00      1.00        10
#                Morgan_Freeman       0.50      0.50      0.50        10
#                   Nancy_Demme       1.00      1.00      1.00        10
#                   Nathan_Lane       1.00      1.00      1.00        10
#                  Nicholas_Tse       1.00      0.70      0.82        10
#                Nicolas_Escude       1.00      1.00      1.00        10
#          Nursultan_Nazarbayev       0.91      1.00      0.95        10
#                     Pat_Burns       1.00      0.70      0.82        10
#                       Pat_Cox       1.00      1.00      1.00        10
#                 Patrick_Ewing       1.00      1.00      1.00        10
#                Peter_Costello       1.00      1.00      1.00        10
#               Peter_Greenaway       1.00      1.00      1.00        10
#                Phil_Mickelson       0.29      0.20      0.24        10
#               Philippe_Noiret       1.00      0.50      0.67        10
#               Princess_Masako       1.00      1.00      1.00        10
#                   Ralph_Klein       1.00      1.00      1.00        10
#          Ricardo_Lopez_Murphy       1.00      1.00      1.00        10
#                 Richard_Haass       1.00      1.00      1.00        10
#              Richard_Sambrook       1.00      1.00      1.00        10
#                  Ricky_Martin       0.83      1.00      0.91        10
#              Robert_Blackwill       1.00      1.00      1.00        10
#                   Robert_Fico       1.00      0.70      0.82        10
#                 Robert_Mugabe       1.00      1.00      1.00        10
#               Rod_Blagojevich       1.00      1.00      1.00        10
#                Rogerio_Romero       1.00      1.00      1.00        10
#                  Scott_Ritter       1.00      1.00      1.00        10
#              Silvio_Fernandez       0.77      1.00      0.87        10
#                Stephen_Daldry       1.00      0.50      0.67        10
#              Stephen_Friedman       1.00      1.00      1.00        10
#                 Terrell_Suggs       1.00      1.00      1.00        10
#                Thomas_Malchow       1.00      1.00      1.00        10
#                     Tom_Jones       1.00      1.00      1.00        10
#                 Tracy_McGrady       1.00      0.50      0.67        10
#                    Tyra_Banks       1.00      1.00      1.00        10
#                  Vaclav_Klaus       1.00      0.50      0.67        10
#                  Wesley_Clark       1.00      1.00      1.00        10
#                  Yossi_Beilin       1.00      1.00      1.00        10
#                  Yuri_Fedotov       1.00      0.50      0.67        10
#
#                      accuracy                           0.89      1000
#                     macro avg       0.94      0.89      0.90      1000
#                  weighted avg       0.94      0.89      0.90      1000
# {'accuracy': 0.892,
#  'precision': 0.9389350926850927,
#  'recall': 0.8919999999999999,
#  'f1_score': 0.901940015915973}

# %%
evaluate_multiclass_one_ori_against_aug(
    data_dir=test_data_dir,
    title="DeepFace - SFace Multi-class Face Recognition (One ORI vs. AUG)",
    model_name="SFace",
    enforce_detection=False,
)
# Out:
# DeepFace - SFace Multi-class Face Recognition (One ORI vs. AUG)
# ===============================================================
# Accuracy : 0.8730
# Precision: 0.9630
# Recall   : 0.8730
# F1-score : 0.8966
#
# Full Classification Report:
#                                precision    recall  f1-score   support
#
#                 Barry_Alvarez       1.00      1.00      1.00        10
#             Begum_Khaleda_Zia       1.00      1.00      1.00        10
#                   Bill_Nelson       1.00      1.00      1.00        10
#              Boris_Berezovsky       1.00      1.00      1.00        10
#                   Brian_Cowen       0.77      1.00      0.87        10
#                    Cesar_Maia       1.00      0.50      0.67        10
#               Charles_Kartman       1.00      1.00      1.00        10
#               Charles_Schumer       1.00      0.80      0.89        10
#                 Chen_Liang_Yu       1.00      1.00      1.00        10
#                  Chris_Tucker       1.00      0.50      0.67        10
#                   Chuck_Amato       1.00      1.00      1.00        10
#                Chung_Mong-hun       1.00      0.50      0.67        10
#                   David_Spade       1.00      1.00      1.00        10
#                Denise_Johnson       1.00      0.50      0.67        10
#               Dennis_Erickson       1.00      1.00      1.00        10
#                 Dennis_Powell       1.00      1.00      1.00        10
#                 Dolma_Tsering       0.67      1.00      0.80        10
#                   Doug_Duncan       1.00      1.00      1.00        10
#                   Eddy_Merckx       1.00      1.00      1.00        10
#              Elizabeth_Taylor       1.00      0.60      0.75        10
#               Ellen_DeGeneres       1.00      0.50      0.67        10
#                  Emile_Lahoud       1.00      0.80      0.89        10
#             Erika_Christensen       1.00      1.00      1.00        10
#             Evander_Holyfield       1.00      0.90      0.95        10
#                Francis_George       1.00      1.00      1.00        10
#                Garry_Kasparov       1.00      1.00      1.00        10
#                   Gary_Forsee       1.00      1.00      1.00        10
#                 Gary_Williams       1.00      0.50      0.67        10
#                  Gary_Winnick       1.00      1.00      1.00        10
#               George_Roy_Hill       1.00      1.00      1.00        10
#              Gerard_Depardieu       1.00      1.00      1.00        10
#                 Gregory_Hines       1.00      1.00      1.00        10
#                 Hanan_Ashrawi       1.00      1.00      1.00        10
#                 Hideki_Matsui       1.00      0.40      0.57        10
#                Hootie_Johnson       0.44      0.40      0.42        10
#                  Howard_Smith       1.00      0.50      0.67        10
#                     Iban_Mayo       1.00      0.70      0.82        10
#                    Iva_Majoli       0.62      0.50      0.56        10
#           Jacqueline_Obradors       1.00      1.00      1.00        10
#            Jada_Pinkett_Smith       1.00      1.00      1.00        10
#                 James_Schultz       1.00      1.00      1.00        10
#           Jean-Claude_Juncker       1.00      1.00      1.00        10
#         Jeffrey_Scott_Postell       1.00      1.00      1.00        10
#             Jennifer_Thompson       1.00      1.00      1.00        10
#                 Jerry_Falwell       1.00      0.50      0.67        10
#                  John_Spencer       1.00      1.00      1.00        10
# Jorge_Rodolfo_Canicoba_Corral       1.00      1.00      1.00        10
#                    Judi_Dench       1.00      1.00      1.00        10
#                 Justin_Gatlin       1.00      1.00      1.00        10
#                 Kathy_Winters       1.00      1.00      1.00        10
#                 Kenneth_Evans       1.00      0.70      0.82        10
#            Kieran_Prendergast       1.00      1.00      1.00        10
#                  Kurt_Russell       1.00      1.00      1.00        10
#             Lawrence_MacAulay       1.00      1.00      1.00        10
#                       Lee_Jun       1.00      1.00      1.00        10
#                Leland_Chapman       1.00      0.50      0.67        10
#                 Lindsay_Benko       1.00      1.00      1.00        10
#                Marilyn_Monroe       1.00      0.50      0.67        10
#                    Mark_Cuban       1.00      1.00      1.00        10
#                 Mark_Hamister       1.00      1.00      1.00        10
#              Miguel_Contreras       1.00      0.80      0.89        10
#             Mikhail_Gorbachev       1.00      1.00      1.00        10
#              Mikulas_Dzurinda       1.00      1.00      1.00        10
#                Morgan_Freeman       1.00      0.50      0.67        10
#                   Nancy_Demme       0.91      1.00      0.95        10
#                   Nathan_Lane       1.00      1.00      1.00        10
#                  Nicholas_Tse       1.00      0.50      0.67        10
#                Nicolas_Escude       1.00      1.00      1.00        10
#          Nursultan_Nazarbayev       1.00      1.00      1.00        10
#                     Pat_Burns       1.00      0.80      0.89        10
#                       Pat_Cox       1.00      1.00      1.00        10
#                 Patrick_Ewing       1.00      1.00      1.00        10
#                Peter_Costello       1.00      0.50      0.67        10
#               Peter_Greenaway       0.91      1.00      0.95        10
#                Phil_Mickelson       0.10      1.00      0.17        10
#               Philippe_Noiret       1.00      0.50      0.67        10
#               Princess_Masako       1.00      1.00      1.00        10
#                   Ralph_Klein       1.00      1.00      1.00        10
#          Ricardo_Lopez_Murphy       1.00      1.00      1.00        10
#                 Richard_Haass       1.00      1.00      1.00        10
#              Richard_Sambrook       1.00      1.00      1.00        10
#                  Ricky_Martin       1.00      0.50      0.67        10
#              Robert_Blackwill       1.00      1.00      1.00        10
#                   Robert_Fico       1.00      0.80      0.89        10
#                 Robert_Mugabe       1.00      1.00      1.00        10
#               Rod_Blagojevich       1.00      1.00      1.00        10
#                Rogerio_Romero       1.00      1.00      1.00        10
#                  Scott_Ritter       0.67      1.00      0.80        10
#              Silvio_Fernandez       1.00      1.00      1.00        10
#                Stephen_Daldry       1.00      0.50      0.67        10
#              Stephen_Friedman       0.71      1.00      0.83        10
#                 Terrell_Suggs       1.00      1.00      1.00        10
#                Thomas_Malchow       1.00      1.00      1.00        10
#                     Tom_Jones       1.00      1.00      1.00        10
#                 Tracy_McGrady       1.00      0.90      0.95        10
#                    Tyra_Banks       1.00      1.00      1.00        10
#                  Vaclav_Klaus       0.50      0.50      0.50        10
#                  Wesley_Clark       1.00      1.00      1.00        10
#                  Yossi_Beilin       1.00      1.00      1.00        10
#                  Yuri_Fedotov       1.00      0.70      0.82        10
#
#                      accuracy                           0.87      1000
#                     macro avg       0.96      0.87      0.90      1000
#                  weighted avg       0.96      0.87      0.90      1000
# {'accuracy': 0.873,
#  'precision': 0.9629971417471417,
#  'recall': 0.873,
#  'f1_score': 0.8965604644603837}
